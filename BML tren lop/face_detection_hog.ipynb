# %%
from PIL import Image
import face_recognition
import matplotlib.pyplot as plt
import cv2
from time import time

#image = face_recognition.load_image_file("test_images/biden.jpg")

image = face_recognition.load_image_file("test_images/test3.jpg")

plt.imshow(image)
plt.show()


t0=time()
face_locations = face_recognition.face_locations(image,number_of_times_to_upsample=1, model="hog")
print('time:',time()-t0)

print("I found {} face(s) in this photograph.".format(len(face_locations)))

for face_location in face_locations:
    top, right, bottom, left = face_location
    image = cv2.rectangle(image,(left,top),(right,bottom),(0,255,0),3)
plt.imshow(image)
plt.show()
# Out:
# time: 0.16957521438598633
# I found 34 face(s) in this photograph.
